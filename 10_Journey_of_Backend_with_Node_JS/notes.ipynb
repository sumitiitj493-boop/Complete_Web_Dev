// %% [markdown]
// <div style="background: linear-gradient(135deg, #0d1117 0%, #161b22 100%); padding: 30px; border-radius: 15px; border-left: 5px solid #58a6ff; margin-bottom: 20px;">
//
// # 🚀 Node.js Masterclass: From Zero to Backend Hero
//
// <p style="color: #8b949e; font-size: 18px; margin-top: 15px;">Your Gateway to Server-Side JavaScript Magic</p>
//
// ---
//
// ### 📚 What You'll Master Today:
//
// | # | Topic | Superpower Unlocked |
// |---|-------|--------------------|
// | 1 | Web Architecture | Understand Frontend vs Backend like a pro |
// | 2 | Node.js Ecosystem | Discover the hidden powers of Node |
// | 3 | npm & Packages | Tap into millions of ready-made solutions |
// | 4 | Core Modules | Master fs, process, os & more |
// | 5 | Build a CLI App | Create a real To-Do app from scratch |
//
// </div>

// %% [markdown]
// ---
//
// # 1. The Big Picture: Web Application Architecture 🏗️
//
// Before diving into Node.js, let's understand WHERE it fits in the web world.

// %% [markdown]
//  <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 1px solid #30363d;">
//
// ### 🌐 The Web Application Universe
//
// <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #c9d1d9; background-color: #0d1117; padding: 20px; border-radius: 8px;">
// ┌────────────────────────────────────────────────────────────────────────────────┐
// │                        WEB APPLICATION ARCHITECTURE                            │
// ├────────────────────────────────────────────────────────────────────────────────┤
// │                                                                                │
// │   ┌─────────────────────┐                    ┌─────────────────────────────┐   │
// │   │     FRONTEND        │                    │         BACKEND             │   │
// │   │    (Browser)        │                    │        (Server)             │   │
// │   │                     │                    │                             │   │
// │   │  ┌───────────────┐  │    HTTP Request    │  ┌───────────────────────┐  │   │
// │   │  │  HTML + CSS   │  │ -----------------> │  │      SERVER           │  │   │
// │   │  │  JavaScript   │  │                    │  │    (Software!)        │  │   │
// │   │  │               │  │ <----------------- │  │                       │  │   │
// │   │  │  React/Vue/   │  │    HTTP Response   │  │  Listens on PORT      │  │   │
// │   │  │  Angular      │  │                    │  │  (e.g., 3000, 8080)   │  │   │
// │   │  └───────────────┘  │                    │  └───────────────────────┘  │   │
// │   │                     │                    │            │                │   │
// │   │   Consumption       │                    │            │ Queries        │   │
// │   │   Happens Here      │                    │            v                │   │
// │   │                     │                    │  ┌───────────────────────┐  │   │
// │   │                     │                    │  │     DATABASE          │  │   │
// │   │                     │                    │  │                       │  │   │
// │   │                     │                    │  │  SQL: MySQL, Postgres │  │   │
// │   │                     │                    │  │  NoSQL: MongoDB       │  │   │
// │   │                     │                    │  └───────────────────────┘  │   │
// │   └─────────────────────┘                    └─────────────────────────────┘   │
// │                                                                                │
// └────────────────────────────────────────────────────────────────────────────────┘
// </pre>
//
// </div>

// %% [markdown]
// <div style="background-color: #1a2332; padding: 20px; border-radius: 10px; border-left: 4px solid #f0883e; margin: 15px 0;">
//
// ### 💡 Key Insight: Server = Software, NOT Hardware!
//
// Many people think servers are just fancy computers in data centers. **WRONG!**
//
// A **server** is simply **software that SERVES you** — it's ready to handle your requests 24/7.
//
// The hardware in data centers just *runs* this server software.
//
// </div>

// %% [markdown]
// ### 📊 Frontend vs Backend: Quick Comparison
//
// | Aspect | Frontend 🎨 | Backend ⚙️ |
// |--------|-------------|------------|
// | **Where** | Browser (Client) | Server (Cloud/Data Center) |
// | **What** | UI, User Experience | Data Processing, Business Logic |
// | **Languages** | HTML, CSS, JavaScript | Node.js, Python, Java, Go |
// | **Frameworks** | React, Vue, Angular | Express, Django, Spring |
// | **Databases** | LocalStorage (limited) | MySQL, MongoDB, PostgreSQL |
// | **User Sees** | Everything! | Nothing (works behind scenes) |

// %% [markdown]
// ### 🔌 What are Ports?
//
// Think of ports like **apartment numbers** in a building:
//
// - Your computer is the building
// - Each port (35,000+ available!) is a different apartment
// - Each server/application lives at a specific port number
//
// | Common Ports | Used For |
// |--------------|----------|
// | 80 | HTTP (web traffic) |
// | 443 | HTTPS (secure web) |
// | 3000 | Development servers |
// | 5432 | PostgreSQL |
// | 27017 | MongoDB |

// %% [markdown]
// ---
//
// # 2. Node.js: The JavaScript Supercharger ⚡
//
// Time to understand what makes Node.js so powerful!

// %% [markdown]
// <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 1px solid #30363d;">
//
// ### 🤔 The JavaScript Problem
//
// JavaScript was originally designed to run **only in browsers**. This means:
//
// | What JS CAN Do (Browser) | What JS CANNOT Do (Alone) |
// |--------------------------|---------------------------|
// | ✅ DOM manipulation | ❌ Read/Write files |
// | ✅ Handle events | ❌ Access operating system |
// | ✅ Fetch API calls | ❌ Create network servers |
// | ✅ Use timers | ❌ Handle TCP/UDP protocols |
// | ✅ LocalStorage | ❌ Interact with databases directly |
//
// **Node.js fills ALL these gaps!** 🎉
//
// </div>

// %% [markdown]
// <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; border: 2px solid #3fb950;">
//
// ### 🎯 What is Node.js?
//
// **Node.js** is a **runtime environment** that allows JavaScript to run **outside the browser**.
//
// It's NOT a programming language — it's a **platform** that extends JavaScript's capabilities!
//
// </div>

// %% [markdown]
// <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #c9d1d9; background-color: #0d1117; padding: 20px; border-radius: 8px;">
// ┌─────────────────────────────────────────────────────────────────────────────────┐
// │                          NODE.JS ECOSYSTEM                                      │
// ├─────────────────────────────────────────────────────────────────────────────────┤
// │                                                                                 │
// │    ┌────────────────────────────────────────────────────────────────────────┐   │
// │    │                         YOUR CODE (JavaScript)                         │   │
// │    │                     You write code HERE only!                          │   │
// │    └────────────────────────────────────────────────────────────────────────┘   │
// │                                     │                                           │
// │                                     v                                           │
// │    ┌────────────────────────────────────────────────────────────────────────┐   │
// │    │                         NODE.JS RUNTIME                                │   │
// │    │  ┌──────────┐ ┌──────────┐ ┌──────────┐ ┌──────────┐ ┌──────────┐      │   │
// │    │  │    fs    │ │  http    │ │   os     │ │  crypto  │ │  events  │      │   │
// │    │  │  (files) │ │ (server) │ │ (system) │ │(security)│ │ (async)  │      │   │
// │    │  └──────────┘ └──────────┘ └──────────┘ └──────────┘ └──────────┘      │   │
// │    │  ┌──────────┐ ┌──────────┐ ┌──────────┐ ┌──────────┐ ┌──────────┐      │   │
// │    │  │   path   │ │   net    │ │  buffer  │ │  stream  │ │   ...    │      │   │
// │    │  └──────────┘ └──────────┘ └──────────┘ └──────────┘ └──────────┘      │   │
// │    └────────────────────────────────────────────────────────────────────────┘   │
// │                                     │                                           │
// │                                     v                                           │
// │    ┌────────────────────────────────────────────────────────────────────────┐   │
// │    │                    LIBUV (Written in C)                                │   │
// │    │         Handles: Event Loop, Async I/O, File System, Network           │   │
// │    └────────────────────────────────────────────────────────────────────────┘   │
// │                                     │                                           │
// │                                     v                                           │
// │    ┌────────────────────────────────────────────────────────────────────────┐   │
// │    │                       OPERATING SYSTEM                                 │   │
// │    │              (Windows / macOS / Linux)                                 │   │
// │    └────────────────────────────────────────────────────────────────────────┘   │
// │                                                                                 │
// └─────────────────────────────────────────────────────────────────────────────────┘
// </pre>

// %% [markdown]
// <div style="background-color: #1c2128; padding: 18px; border-radius: 10px; border-left: 4px solid #a371f7; margin: 15px 0;">
//
// ### 🔮 What is Libuv?
//
// **Libuv** is a C library that provides:
// - **Event Loop** — The heart of async operations
// - **Asynchronous I/O** — Non-blocking file and network operations
// - **Thread Pool** — For heavy operations
//
// You never interact with Libuv directly — Node.js wraps it in a beautiful JavaScript API!
//
// > **Fun Fact:** The source code of Libuv is pure C programming. Node.js does the heavy lifting so you don't have to!
//
// </div>

// %% [markdown]
// ### 📦 Core Node.js Modules
//
// | Module | Purpose | Example Use |
// |--------|---------|-------------|
// | `fs` | File System operations | Read/write files |
// | `http` | Create HTTP servers | Build web servers |
// | `https` | Secure HTTP servers | SSL/TLS connections |
// | `path` | File path utilities | Join, resolve paths |
// | `os` | Operating System info | CPU, memory, hostname |
// | `crypto` | Cryptography | Hashing, encryption |
// | `events` | Event handling | Custom event emitters |
// | `net` | Low-level networking | TCP servers/clients |
// | `buffer` | Binary data handling | Raw memory operations |
// | `stream` | Streaming data | Large file processing |

// %% [markdown]
// ---
//
// # 3. npm: Your Package Treasure Chest 📦
//
// The world's largest software registry at your fingertips!

// %% [markdown]
// <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 1px solid #30363d;">
//
// ### 🎁 What is npm?
//
// **npm** comes bundled with Node.js installation.
//
// > 💡 **Fun Fact:** npm is NOT "Node Package Manager" — it's just **npm**! The creators confirmed there's no official full form.
//
// </div>

// %% [markdown]
// <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #c9d1d9; background-color: #0d1117; padding: 20px; border-radius: 8px;">
// ┌────────────────────────────────────────────────────────────────────────────┐
// │                           npm ECOSYSTEM                                    │
// ├────────────────────────────────────────────────────────────────────────────┤
// │                                                                            │
// │      ┌─────────────────────────────────────────────────────────────┐       │
// │      │                    YOUR PROJECT                             │       │
// │      │                                                             │       │
// │      │   ┌─────────────┐    ┌─────────────┐    ┌─────────────┐     │       │
// │      │   │  Your Code  │    │ Node.js     │    │Third Party  │     │       │
// │      │   │ (index.js)  │    │  Modules    │    │  Packages   │     │       │
// │      │   │             │    │ (fs, http)  │    │(from npm)   │     │       │
// │      │   └─────────────┘    └─────────────┘    └─────────────┘     │       │
// │      │                                              ^              │       │
// │      └──────────────────────────────────────────────│──────────────┘       │
// │                                                     │                      │
// │                                         npm install │                      │
// │                                                     │                      │
// │      ┌──────────────────────────────────────────────v──────────────┐       │
// │      │                   npm REGISTRY                              │       │
// │      │              (2+ Million Packages!)                         │       │
// │      │                                                             │       │
// │      │   express    react    lodash    axios    date-fns   ...     │       │
// │      │                                                             │       │
// │      └─────────────────────────────────────────────────────────────┘       │
// │                                                                            │
// └────────────────────────────────────────────────────────────────────────────┘
// </pre>

// %% [markdown]
// ### 🌟 Popular npm Packages
//
// | Package | Weekly Downloads | What it Does |
// |---------|------------------|---------------|
// | **express** | 30M+ | Web framework for Node.js |
// | **lodash** | 50M+ | Utility functions |
// | **axios** | 45M+ | HTTP client |
// | **date-fns** | 20M+ | Date manipulation |
// | **mongoose** | 3M+ | MongoDB ODM |

// %% [markdown]
// ### 🛠️ Basic npm Commands
//
// ```bash
// # Initialize a new project
// npm init
//
// # Install a package
// npm install express
//
// # Install as dev dependency
// npm install --save-dev nodemon
//
// # Install globally
// npm install -g typescript
//
// # Run scripts from package.json
// npm run start
// ```

// %% [markdown]
// ---
//
// # 4. Understanding process.argv 🎯
//
// How to capture command-line arguments in Node.js

// %% [markdown]
// <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 1px solid #30363d;">
//
// ### 📥 The process Object
//
// The `process` object is a **global** in Node.js — no import needed!
//
// It provides information about the current Node.js process.
//
// </div>

// %% [markdown]
// <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #c9d1d9; background-color: #0d1117; padding: 20px; border-radius: 8px;">
// ┌─────────────────────────────────────────────────────────────────────────────────┐
// │                         process.argv BREAKDOWN                                  │
// ├─────────────────────────────────────────────────────────────────────────────────┤
// │                                                                                 │
// │   Command:  node  todo/todo.js  add  "buy milk"                                 │
// │                                                                                 │
// │   process.argv returns an ARRAY:                                                │
// │                                                                                 │
// │   ┌─────────────────────────────────────────────────────────────────────────┐   │
// │   │ Index │ Value                    │ What it is                           │   │
// │   ├───────┼──────────────────────────┼──────────────────────────────────────┤   │
// │   │   0   │ /usr/bin/node            │ Path to Node.js executable           │   │
// │   │   1   │ /path/to/todo.js         │ Path to your script file             │   │
// │   │   2   │ add                      │ First argument (COMMAND)             │   │
// │   │   3   │ buy milk                 │ Second argument (DATA)               │   │
// │   └───────┴──────────────────────────┴──────────────────────────────────────┘   │
// │                                                                                 │
// │   YOUR ARGUMENTS START FROM INDEX 2!                                            │
// │                                                                                 │
// └─────────────────────────────────────────────────────────────────────────────────┘
// </pre>

// %% [markdown]
// ### 💻 Code Example: Capturing Arguments
//
// ```javascript
// // No import needed - process is global!
//
// const command = process.argv[2];  // 'add', 'list', 'remove'
// const argument = process.argv[3]; // 'buy milk', '1', etc.
//
// console.log('Command:', command);
// console.log('Argument:', argument);
// ```
//
// **Output:**
// ```
// $ node app.js add "buy milk"
// Command: add
// Argument: buy milk
// ```

// %% [markdown]
// ---
//
// # 5. File System Module (fs) Deep Dive 📁
//
// The most important module for file operations!

// %% [markdown]
// <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; border: 2px solid #58a6ff;">
//
// ### 📂 Importing the fs Module
//
// ```javascript
// // Using require (CommonJS - Node.js default)
// const fs = require('fs');
//
// // Using import (ES Modules - needs package.json config)
// import fs from 'fs';
// ```
//
// </div>

// %% [markdown]
// ### ⚡ Sync vs Async Operations
//
// | Aspect | Synchronous | Asynchronous |
// |--------|-------------|---------------|
// | **Method** | `readFileSync()` | `readFile()` |
// | **Blocking** | YES - blocks main thread | NO - non-blocking |
// | **Use When** | Must complete before continuing | Can run in background |
// | **Example** | Bank deposit (critical) | Log file writing |
//
// > 💡 **Tip:** Use `Sync` versions when the operation MUST complete before anything else happens!

// %% [markdown]
// <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #c9d1d9; background-color: #0d1117; padding: 20px; border-radius: 8px;">
// ┌─────────────────────────────────────────────────────────────────────────────────┐
// │                       FILE READING PIPELINE                                     │
// ├─────────────────────────────────────────────────────────────────────────────────┤
// │                                                                                 │
// │   ┌──────────────┐     ┌──────────────┐     ┌──────────────┐     ┌──────────┐   │
// │   │    FILE      │     │    DATA      │     │    DATA      │     │  USABLE  │   │
// │   │  (tasks.json)│ --> │   BUFFER     │ --> │    JSON      │ --> │  OBJECT  │   │
// │   │              │     │  (raw bytes) │     │  (string)    │     │  (parsed)│   │
// │   └──────────────┘     └──────────────┘     └──────────────┘     └──────────┘   │
// │                              │                     │                    │       │
// │                              │                     │                    │       │
// │                              v                     v                    v       │
// │                        .toString()           JSON.parse()         Ready!        │
// │                                                                                 │
// └─────────────────────────────────────────────────────────────────────────────────┘
// </pre>

// %% [markdown]
// <div style="background-color: #1c2128; padding: 18px; border-radius: 10px; border-left: 4px solid #f0883e; margin: 15px 0;">
//
// ### 🔑 Key Concept: Data Buffer
//
// When you read a file, you DON'T get a string directly!
//
// You get a **Buffer** — raw binary data that needs conversion:
//
// 1. **Buffer** → Call `.toString()` → **String**
// 2. **String** → Call `JSON.parse()` → **JavaScript Object**
//
// </div>

// %% [markdown]
// ### 📖 Reading Files: Complete Code
//
// ```javascript
// const fs = require('fs');
//
// const loadTasks = () => {
//     try {
//         // Step 1: Read file (returns Buffer)
//         const dataBuffer = fs.readFileSync('tasks.json');
//
//         // Step 2: Convert Buffer to String
//         const dataJSON = dataBuffer.toString();
//
//         // Step 3: Parse String to JavaScript Object
//         return JSON.parse(dataJSON);
//
//     } catch (error) {
//         // File doesn't exist? Return empty array!
//         return [];
//     }
// };
// ```

// %% [markdown]
// <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #c9d1d9; background-color: #0d1117; padding: 20px; border-radius: 8px;">
// ┌─────────────────────────────────────────────────────────────────────────────────┐
// │                       FILE WRITING PIPELINE                                     │
// ├─────────────────────────────────────────────────────────────────────────────────┤
// │                                                                                 │
// │   ┌──────────────┐     ┌──────────────┐     ┌──────────────────────────────┐   │
// │   │  JavaScript  │     │    JSON      │     │          FILE                │   │
// │   │   Object     │ --> │   String     │ --> │       (tasks.json)           │   │
// │   │   (array)    │     │              │     │                              │   │
// │   └──────────────┘     └──────────────┘     └──────────────────────────────┘   │
// │          │                    │                          │                      │
// │          │                    │                          │                      │
// │          v                    v                          v                      │
// │   JSON.stringify()     writeFileSync()              Saved!                     │
// │                                                                                 │
// └─────────────────────────────────────────────────────────────────────────────────┘
// </pre>

// %% [markdown]
// ### ✍️ Writing Files: Complete Code
//
// ```javascript
// const fs = require('fs');
//
// const saveTasks = (tasks) => {
//     // Step 1: Convert JavaScript Object to JSON String
//     const dataJSON = JSON.stringify(tasks);
//
//     // Step 2: Write to file (creates file if doesn't exist!)
//     fs.writeFileSync('tasks.json', dataJSON);
// };
// ```
//
// > 💡 **Magic:** `writeFileSync` automatically creates the file if it doesn't exist!

// %% [markdown]
// ---
//
// # 6. Building the To-Do CLI Application 🛠️
//
// Let's put it all together and build something real!

// %% [markdown]
// <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 1px solid #30363d;">
//
// ### 📋 Application Features
//
// | Command | Action | Example |
// |---------|--------|----------|
// | `add` | Add a new task | `node todo.js add "buy milk"` |
// | `list` | List all tasks | `node todo.js list` |
// | `remove` | Remove a task by ID | `node todo.js remove 1` |
//
// </div>

// %% [markdown]
// <pre style="white-space: pre; font-family: monospace; overflow-x: auto; color: #c9d1d9; background-color: #0d1117; padding: 20px; border-radius: 8px;">
// ┌─────────────────────────────────────────────────────────────────────────────────┐
// │                    TODO APP ARCHITECTURE                                        │
// ├─────────────────────────────────────────────────────────────────────────────────┤
// │                                                                                 │
// │   ┌─────────────────────────────────────────────────────────────────────────┐  │
// │   │                         todo.js                                         │  │
// │   ├─────────────────────────────────────────────────────────────────────────┤  │
// │   │                                                                         │  │
// │   │   process.argv ───────> Command Router                                  │  │
// │   │                              │                                          │  │
// │   │              ┌───────────────┼───────────────┐                          │  │
// │   │              v               v               v                          │  │
// │   │        ┌─────────┐     ┌─────────┐     ┌─────────┐                     │  │
// │   │        │  add    │     │  list   │     │ remove  │                     │  │
// │   │        │  Task   │     │  Tasks  │     │  Task   │                     │  │
// │   │        └────┬────┘     └────┬────┘     └────┬────┘                     │  │
// │   │             │               │               │                          │  │
// │   │             v               v               v                          │  │
// │   │        ┌─────────────────────────────────────────┐                     │  │
// │   │        │          loadTasks()                    │                     │  │
// │   │        │     (Read from tasks.json)              │                     │  │
// │   │        └─────────────────────────────────────────┘                     │  │
// │   │                          │                                              │  │
// │   │                          v                                              │  │
// │   │        ┌─────────────────────────────────────────┐                     │  │
// │   │        │          saveTasks()                    │                     │  │
// │   │        │     (Write to tasks.json)               │                     │  │
// │   │        └─────────────────────────────────────────┘                     │  │
// │   │                                                                         │  │
// │   └─────────────────────────────────────────────────────────────────────────┘  │
// │                                    │                                           │
// │                                    v                                           │
// │   ┌─────────────────────────────────────────────────────────────────────────┐  │
// │   │                         tasks.json                                      │  │
// │   │              [{"task": "buy milk"}, {"task": "code"}]                  │  │
// │   └─────────────────────────────────────────────────────────────────────────┘  │
// │                                                                                 │
// └─────────────────────────────────────────────────────────────────────────────────┘
// </pre>

// %% [markdown]
// ### 📝 Complete Source Code: todo.js
//
// ```javascript
// // ==========================================
// //           TODO CLI APPLICATION
// // ==========================================
//
// // Import the File System module
// const fs = require('fs');
//
// // Define file path for storing tasks
// const filePath = 'tasks.json';
//
// // ==========================================
// //           UTILITY FUNCTIONS
// // ==========================================
//
// // Load all tasks from the JSON file
// const loadTasks = () => {
//     try {
//         const dataBuffer = fs.readFileSync(filePath);
//         const dataJSON = dataBuffer.toString();
//         return JSON.parse(dataJSON);
//     } catch (error) {
//         // File doesn't exist or is empty
//         return [];
//     }
// };
//
// // Save all tasks to the JSON file
// const saveTasks = (tasks) => {
//     const dataJSON = JSON.stringify(tasks);
//     fs.writeFileSync(filePath, dataJSON);
// };
//
// // ==========================================
// //           COMMAND FUNCTIONS
// // ==========================================
//
// // Add a new task
// const addTask = (task) => {
//     const tasks = loadTasks();
//     tasks.push({ task: task });
//     saveTasks(tasks);
//     console.log('Task added:', task);
// };
//
// // List all tasks
// const listTasks = () => {
//     const tasks = loadTasks();
//     tasks.forEach((task, index) => {
//         console.log(`${index + 1}. ${task.task}`);
//     });
// };
//
// // Remove a task by index
// const removeTask = (index) => {
//     const tasks = loadTasks();
//     // User gives 1-based index, convert to 0-based
//     tasks.splice(index - 1, 1);
//     saveTasks(tasks);
//     console.log('Task removed!');
// };
//
// // ==========================================
// //           COMMAND ROUTER
// // ==========================================
//
// const command = process.argv[2];
// const argument = process.argv[3];
//
// if (command === 'add') {
//     addTask(argument);
// } else if (command === 'list') {
//     listTasks();
// } else if (command === 'remove') {
//     removeTask(parseInt(argument));
// } else {
//     console.log('Command not recognized!');
// }
// ```

// %% [markdown]
// ### 🖥️ Running the Application
//
// ```bash
// # Add tasks
// $ node todo.js add "buy milk"
// Task added: buy milk
//
// $ node todo.js add "record videos"
// Task added: record videos
//
// # List all tasks
// $ node todo.js list
// 1. buy milk
// 2. record videos
//
// # Remove a task
// $ node todo.js remove 1
// Task removed!
//
// # List again to verify
// $ node todo.js list
// 1. record videos
// ```

// %% [markdown]
// ### 📄 Generated tasks.json
//
// ```json
// [{"task":"buy milk"},{"task":"record videos"}]
// ```

// %% [markdown]
// ---
//
// # 7. Common Bugs & Debugging 🐛

// %% [markdown]
// <div style="background-color: #2d1b1b; padding: 20px; border-radius: 10px; border-left: 4px solid #f85149; margin: 15px 0;">
//
// ### ⚠️ Bug: "Converting circular structure to JSON"
//
// **What it means:** You're accidentally pushing the entire array into itself!
//
// **Wrong Code:**
// ```javascript
// tasks.push(tasks);  // WRONG! Pushing array into itself
// ```
//
// **Correct Code:**
// ```javascript
// tasks.push({ task: task });  // RIGHT! Push an object
// ```
//
// </div>

// %% [markdown]
// <div style="background-color: #1c2128; padding: 18px; border-radius: 10px; border-left: 4px solid #f0883e; margin: 15px 0;">
//
// ### 💡 Remember: Command Line Arguments are STRINGS!
//
// Everything from the command line comes as a **string**.
//
// ```javascript
// // User types: node todo.js remove 1
//
// const argument = process.argv[3];  // "1" (string!)
//
// // Convert to number for array operations
// const index = parseInt(argument);  // 1 (number)
// ```
//
// </div>

// %% [markdown]
// ---
//
// # 8. OS Module Bonus 💻
//
// A quick peek at what else Node.js can do!

// %% [markdown]
// ```javascript
// const os = require('os');
//
// console.log('CPU Architecture:', os.arch());
// console.log('Platform:', os.platform());
// console.log('Hostname:', os.hostname());
// console.log('Total Memory:', os.totalmem() / 1024 / 1024 / 1024, 'GB');
// console.log('Free Memory:', os.freemem() / 1024 / 1024 / 1024, 'GB');
// console.log('Home Directory:', os.homedir());
// console.log('Temp Directory:', os.tmpdir());
// console.log('CPU Cores:', os.cpus().length);
// ```
//
// **Sample Output:**
// ```
// CPU Architecture: x64
// Platform: darwin
// Hostname: MacBook-Pro
// Total Memory: 16 GB
// Free Memory: 4.5 GB
// Home Directory: /Users/developer
// Temp Directory: /var/folders/...
// CPU Cores: 8
// ```

// %% [markdown]
// ---
//
// # 9. Quick Revision Table 📋

// %% [markdown]
// <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 2px solid #3fb950;">
//
// | Concept | Key Point | Code/Example |
// |---------|-----------|---------------|
// | **Server** | Software, not hardware! | Serves requests 24/7 |
// | **Port** | Virtual address for server | 3000, 8080, 443 |
// | **Node.js** | JS runtime for server-side | Extends JS capabilities |
// | **Libuv** | C library for async I/O | Hidden under the hood |
// | **npm** | Package manager (just npm!) | `npm install express` |
// | **require()** | Import modules (CommonJS) | `const fs = require('fs')` |
// | **process.argv** | Command line arguments | Array starting at index 2 |
// | **fs.readFileSync** | Read file (blocking) | Returns Buffer |
// | **fs.writeFileSync** | Write file (blocking) | Creates file if missing |
// | **Buffer** | Raw binary data | Convert with `.toString()` |
// | **JSON.parse()** | String → Object | Parse JSON data |
// | **JSON.stringify()** | Object → String | Prepare for file write |
//
// </div>

// %% [markdown]
// ---
//
// # 10. Memory Tricks 🧠

// %% [markdown]
// <div style="background-color: #1a2332; padding: 20px; border-radius: 10px; border-left: 4px solid #a371f7;">
//
// ### 🎯 Mnemonics to Remember
//
// **1. process.argv indices: "01 are BORING, 2+ are YOURS"**
// - Index 0 & 1 = Node path & file path (boring!)
// - Index 2+ = Your actual arguments
//
// ---
//
// **2. File Reading: "BTS" - Buffer → ToString → parse(String)**
// - **B**uffer from `readFileSync`
// - **T**oString to convert
// - **S**tring parsed with JSON.parse
//
// ---
//
// **3. File Writing: "SO" - Stringify → writeO(utput)**
// - **S**tringify the object
// - **O**utput with writeFileSync
//
// ---
//
// **4. Sync vs Async: "Sync = STOP, Async = GO"**
// - Sync = Everything STOPS until done
// - Async = Other things can GO on
//
// </div>

// %% [markdown]
// <div style="background-color: #0d1117; padding: 20px; border-radius: 10px; border: 2px solid #58a6ff; margin: 15px 0;">
//
// ### 🎪 Fun Analogy: Restaurant
//
// | Concept | Restaurant Analogy |
// |---------|--------------------|
// | **Server** | The waiter (serves your requests) |
// | **Port** | Table number (where to find you) |
// | **API** | The menu (interface to order food) |
// | **Database** | The kitchen (stores & processes ingredients) |
// | **Frontend** | The dining area (what customers see) |
// | **Backend** | Kitchen + Storage (hidden from customers) |
//
// </div>

// %% [markdown]
// ---
//
// # 11. One-Liners to Remember 📝

// %% [markdown]
// <div style="background-color: #161b22; padding: 25px; border-radius: 10px; border: 1px solid #30363d;">
//
// ```
// 💎 "A SERVER is software that SERVES - always ready, always listening."
//
// 💎 "Node.js doesn't replace JavaScript - it SUPERCHARGES it."
//
// 💎 "npm has 2M+ packages - don't reinvent wheels, install them."
//
// 💎 "Buffer is raw data - always .toString() before using."
//
// 💎 "Sync blocks the world, Async lets it spin."
//
// 💎 "process.argv[2] is where YOUR story begins."
//
// 💎 "JSON.parse() reads the world, JSON.stringify() writes it."
//
// 💎 "writeFileSync creates files magically - no mkdir needed."
//
// 💎 "try-catch is your safety net when files might not exist."
//
// 💎 "Everything from command line is a STRING - parseInt when needed."
// ```
//
// </div>

// %% [markdown]
// ---
//
// # 12. What's Next? 🚀

// %% [markdown]
// <div style="background: linear-gradient(135deg, #161b22 0%, #0d1117 100%); padding: 25px; border-radius: 15px; border: 2px solid #3fb950;">
//
// ### 🗺️ Your Node.js Journey Map
//
// ```
// ✅ COMPLETED: Basic Node.js & File System
//        |
//        v
// 📍 NEXT UP: npm & Third-Party Packages
//        |
//        v
// 🔮 COMING: HTTP Module & Building Servers
//        |
//        v
// 🌟 FUTURE: Express.js & Full-Stack Apps
//        |
//        v
// 🏆 GOAL: Deploy Real Applications!
// ```
//
// </div>

// %% [markdown]
// <div style="background-color: #0d1117; padding: 30px; border-radius: 15px; border: 2px solid #a371f7; text-align: center; margin-top: 20px;">
//
// ## 🎉 Congratulations!
//
// You've unlocked the power of **Node.js**!
//
// You can now:
// - ✅ Read and write files with JavaScript
// - ✅ Build command-line applications
// - ✅ Understand the web architecture
// - ✅ Use process.argv for CLI arguments
// - ✅ Handle JSON data like a pro
//
// ---
//
// *"The journey of a thousand miles begins with a single `npm install`"* 😄
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #a371f7 0%, #58a6ff 100%); padding: 30px; border-radius: 15px; text-align: center; margin-top: 20px;">
//
// <h2 style="color: white; margin-bottom: 15px;">🙏 Thank You for Learning!</h2>
//
// <p style="color: #ffffff; font-size: 1.2em;">
// Bhai, tu ab Node.js developer ban gaya! 🎊<br><br>
// Aage Express.js, MongoDB, aur full-stack apps banayenge!<br><br>
// <strong>Keep Coding, Keep Growing!</strong> 🚀
// </p>
//
// </div>
